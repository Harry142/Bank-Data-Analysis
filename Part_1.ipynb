-- %% [markdown]
-- # [VPBankTest]

-- %%
USE [master]
GO

-- %%
/****** Object:  Database [VPBankTest]    Script Date: 12/25/2023 1:23:10 AM ******/
CREATE DATABASE [VPBankTest]
 CONTAINMENT = NONE
 ON  PRIMARY 
( NAME = N'VPBankTest', FILENAME = N'C:\Program Files\Microsoft SQL Server\MSSQL15.SQLEXPRESS\MSSQL\DATA\VPBankTest.mdf' , SIZE = 139264KB , MAXSIZE = UNLIMITED, FILEGROWTH = 65536KB )
 LOG ON 
( NAME = N'VPBankTest_log', FILENAME = N'C:\Program Files\Microsoft SQL Server\MSSQL15.SQLEXPRESS\MSSQL\DATA\VPBankTest_log.ldf' , SIZE = 8192KB , MAXSIZE = 2048GB , FILEGROWTH = 65536KB )
 WITH CATALOG_COLLATION = DATABASE_DEFAULT
GO
ALTER DATABASE [VPBankTest] SET COMPATIBILITY_LEVEL = 150
GO
IF (1 = FULLTEXTSERVICEPROPERTY('IsFullTextInstalled'))
begin
EXEC [VPBankTest].[dbo].[sp_fulltext_database] @action = 'enable'
end
GO
ALTER DATABASE [VPBankTest] SET ANSI_NULL_DEFAULT OFF 
GO
ALTER DATABASE [VPBankTest] SET ANSI_NULLS OFF 
GO
ALTER DATABASE [VPBankTest] SET ANSI_PADDING OFF 
GO
ALTER DATABASE [VPBankTest] SET ANSI_WARNINGS OFF 
GO
ALTER DATABASE [VPBankTest] SET ARITHABORT OFF 
GO
ALTER DATABASE [VPBankTest] SET AUTO_CLOSE OFF 
GO
ALTER DATABASE [VPBankTest] SET AUTO_SHRINK OFF 
GO
ALTER DATABASE [VPBankTest] SET AUTO_UPDATE_STATISTICS ON 
GO
ALTER DATABASE [VPBankTest] SET CURSOR_CLOSE_ON_COMMIT OFF 
GO
ALTER DATABASE [VPBankTest] SET CURSOR_DEFAULT  GLOBAL 
GO
ALTER DATABASE [VPBankTest] SET CONCAT_NULL_YIELDS_NULL OFF 
GO
ALTER DATABASE [VPBankTest] SET NUMERIC_ROUNDABORT OFF 
GO
ALTER DATABASE [VPBankTest] SET QUOTED_IDENTIFIER OFF 
GO
ALTER DATABASE [VPBankTest] SET RECURSIVE_TRIGGERS OFF 
GO
ALTER DATABASE [VPBankTest] SET  DISABLE_BROKER 
GO
ALTER DATABASE [VPBankTest] SET AUTO_UPDATE_STATISTICS_ASYNC OFF 
GO
ALTER DATABASE [VPBankTest] SET DATE_CORRELATION_OPTIMIZATION OFF 
GO
ALTER DATABASE [VPBankTest] SET TRUSTWORTHY OFF 
GO
ALTER DATABASE [VPBankTest] SET ALLOW_SNAPSHOT_ISOLATION OFF 
GO
ALTER DATABASE [VPBankTest] SET PARAMETERIZATION SIMPLE 
GO
ALTER DATABASE [VPBankTest] SET READ_COMMITTED_SNAPSHOT OFF 
GO
ALTER DATABASE [VPBankTest] SET HONOR_BROKER_PRIORITY OFF 
GO
ALTER DATABASE [VPBankTest] SET RECOVERY SIMPLE 
GO
ALTER DATABASE [VPBankTest] SET  MULTI_USER 
GO
ALTER DATABASE [VPBankTest] SET PAGE_VERIFY CHECKSUM  
GO
ALTER DATABASE [VPBankTest] SET DB_CHAINING OFF 
GO
ALTER DATABASE [VPBankTest] SET FILESTREAM( NON_TRANSACTED_ACCESS = OFF ) 
GO
ALTER DATABASE [VPBankTest] SET TARGET_RECOVERY_TIME = 60 SECONDS 
GO
ALTER DATABASE [VPBankTest] SET DELAYED_DURABILITY = DISABLED 
GO
ALTER DATABASE [VPBankTest] SET ACCELERATED_DATABASE_RECOVERY = OFF  
GO
ALTER DATABASE [VPBankTest] SET QUERY_STORE = OFF
GO

-- %% [markdown]
-- # [dbo].[Contact_table$]

-- %%
USE [VPBankTest]
GO

-- %%
/****** Object:  Table [dbo].[Contact_table$]    Script Date: 12/25/2023 1:23:10 AM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Contact_table$](
	[ID_] [float] NULL,
	[Phone] [nvarchar](255) NULL
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Department_table$]

-- %%
/****** Object:  Table [dbo].[Department_table$]    Script Date: 12/25/2023 1:23:10 AM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Department_table$](
	[Department_id] [float] NULL,
	[Department_name] [nvarchar](255) NULL
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Library_table$]

-- %%
/****** Object:  Table [dbo].[Library_table$]    Script Date: 12/25/2023 1:23:10 AM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Library_table$](
	[Date] [datetime] NULL,
	[User_name] [nvarchar](255) NULL,
	[Book_type] [nvarchar](255) NULL
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Order_table$]

-- %%
/****** Object:  Table [dbo].[Order_table$]    Script Date: 12/25/2023 1:23:10 AM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Order_table$](
	[Order_Id] [float] NULL,
	[Client_Id] [float] NULL,
	[Driver_Id] [float] NULL,
	[City_Id] [float] NULL,
	[Status] [nvarchar](255) NULL,
	[Request_date] [nvarchar](255) NULL
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Staff_table$]

-- %%
/****** Object:  Table [dbo].[Staff_table$]    Script Date: 12/25/2023 1:23:10 AM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Staff_table$](
	[Staff_id] [float] NULL,
	[Staff_name] [nvarchar](255) NULL,
	[Salary] [float] NULL,
	[Department_Id] [float] NULL
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[User_table$]

-- %%
/****** Object:  Table [dbo].[User_table$]    Script Date: 12/25/2023 1:23:10 AM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[User_table$](
	[User_Id] [float] NULL,
	[Banned] [nvarchar](255) NULL,
	[User_type] [nvarchar](255) NULL
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Visitor_table$]

-- %%
/****** Object:  Table [dbo].[Visitor_table$]    Script Date: 12/25/2023 1:23:10 AM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Visitor_table$](
	[Visit_date] [datetime] NULL,
	[No_of_visitors] [float] NULL
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [VPBankTest]

-- %%
USE [master]
GO

-- %%
ALTER DATABASE [VPBankTest] SET  READ_WRITE 
GO
